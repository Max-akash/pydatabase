# 42  12/21/19  Central   Martha     Steven  Home Theater   28.0      500.00
# 43       NaN      NaN      NaN        NaN           NaN    NaN          NaN
# 44       NaN      NaN      NaN        NaN           NaN    NaN          NaN
#
#         Sale_amt
# 0    113,810.00
# 1     25,000.00
# 2     43,128.00
# 3      6,075.00
# 4     67,088.00
# 5     30,000.00
# 6     89,850.00
# 7    107,820.00
# 8     38,336.00
# 9     30,000.00
# 10   107,820.00
# 11    14,500.00
# 12    40,500.00
# 13    41,930.00
# 14       250.00
# 15       936.00
# 16    14,000.00
# 17    14,400.00
# 18     3,375.00
# 19     5,616.00
# 20    80,266.00
# 21     4,329.00
# 22    23,000.00
# 23    43,500.00
# 24     2,000.00
# 25     3,500.00
# 26     2,925.00
# 27    79,068.00
# 28    21,600.00
# 29    63,494.00
# 30    40,000.00
# 31       625.00
# 32     3,627.00
# 33     3,217.50
# 34     2,457.00
# 35       375.00
# 36     8,386.00
# 37    17,100.00
# 38    28,500.00
# 39    16,772.00
# 40     5,500.00
# 41    47,000.00
# 42    14,000.00
# 43           NaN
# 44           NaN

# %%
df1 =pd.pivot_table(df,index=['Manager','Region','OrderDate','SalesMan']).head()
df1
# Out:
#                                     Units
# Manager Region  OrderDate SalesMan
# Douglas Central 12/12/18  John       67.0
#                 2/1/19    John       87.0
#                 9/1/18    John        2.0
#         East    11/8/18   Karen      15.0
#                 12/29/18  Karen      74.0

# %% [markdown]
# 2. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise.

# %%
df2 =pd.pivot_table(df,index=['Sale_amt'],columns=['Region','Manager'])
df2
# Out:
#                Units
# Region       Central                           East           West
# Manager      Douglas Hermann Martha Timothy Douglas Martha Douglas Timothy
# Sale_amt
#  107,820.00      NaN    90.0    NaN     NaN     NaN    NaN     NaN     NaN
#  113,810.00      NaN     NaN    NaN     NaN     NaN   95.0     NaN     NaN
#  14,000.00       NaN    28.0   28.0     NaN     NaN    NaN     NaN     NaN
#  14,400.00       NaN     NaN    NaN     NaN     NaN   64.0     NaN     NaN
#  14,500.00       NaN     NaN    NaN     NaN     NaN   29.0     NaN     NaN
#  16,772.00       NaN     NaN   14.0     NaN     NaN    NaN     NaN     NaN
#  17,100.00       NaN     NaN    NaN     NaN     NaN    NaN     NaN    76.0
#  2,000.00        NaN     NaN    NaN     NaN     NaN    4.0     NaN     NaN
#  2,457.00        NaN    42.0    NaN     NaN     NaN    NaN     NaN     NaN
#  2,925.00        NaN    50.0    NaN     NaN     NaN    NaN     NaN     NaN
#  21,600.00       NaN     NaN    NaN     NaN     NaN   96.0     NaN     NaN
#  23,000.00       NaN     NaN    NaN    46.0     NaN    NaN     NaN     NaN
#  25,000.00       NaN    50.0    NaN     NaN     NaN    NaN     NaN     NaN
#  250.00          2.0     NaN    NaN     NaN     NaN    NaN     NaN     NaN
#  28,500.00       NaN     NaN    NaN     NaN     NaN    NaN    57.0     NaN
#  3,217.50        NaN    55.0    NaN     NaN     NaN    NaN     NaN     NaN
#  3,375.00        NaN     NaN    NaN     NaN    15.0    NaN     NaN     NaN
#  3,500.00        NaN     NaN    NaN     NaN     NaN    NaN     NaN     7.0
#  3,627.00        NaN     NaN    NaN     NaN     NaN   62.0     NaN     NaN
#  30,000.00       NaN     NaN    NaN     NaN     NaN   60.0     NaN     NaN
#  375.00          NaN     NaN    NaN     NaN     NaN    NaN     NaN     3.0
#  38,336.00       NaN     NaN    NaN     NaN     NaN    NaN    32.0     NaN
#  4,329.00        NaN     NaN    NaN     NaN    74.0    NaN     NaN     NaN
#  40,000.00       NaN     NaN    NaN    80.0     NaN    NaN     NaN     NaN
#  40,500.00       NaN     NaN    NaN     NaN    81.0    NaN     NaN     NaN
#  41,930.00       NaN     NaN    NaN     NaN     NaN   35.0     NaN     NaN
#  43,128.00       NaN    36.0    NaN     NaN     NaN    NaN     NaN     NaN
#  43,500.00      87.0     NaN    NaN     NaN     NaN    NaN     NaN     NaN
#  47,000.00       NaN    94.0    NaN     NaN     NaN    NaN     NaN     NaN
#  5,500.00        NaN    11.0    NaN     NaN     NaN    NaN     NaN     NaN
#  5,616.00        NaN    96.0    NaN     NaN     NaN    NaN     NaN     NaN
#  6,075.00        NaN     NaN    NaN    27.0     NaN    NaN     NaN     NaN
#  625.00          NaN     5.0    NaN     NaN     NaN    NaN     NaN     NaN
#  63,494.00       NaN     NaN    NaN    53.0     NaN    NaN     NaN     NaN
#  67,088.00       NaN     NaN    NaN     NaN     NaN    NaN     NaN    56.0
#  79,068.00       NaN     NaN   66.0     NaN     NaN    NaN     NaN     NaN
#  8,386.00        NaN     NaN    NaN     7.0     NaN    NaN     NaN     NaN
#  80,266.00      67.0     NaN    NaN     NaN     NaN    NaN     NaN     NaN
#  89,850.00       NaN     NaN   75.0     NaN     NaN    NaN     NaN     NaN
#  936.00          NaN     NaN    NaN     NaN     NaN   16.0     NaN     NaN

# %% [markdown]
# 3. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise.

# %%
table= pd.pivot_table(df,index=(['Region','Manager','SalesMan']),values='Sale_amt',aggfunc='count')
table
# Out:
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John              3
#         Hermann Luis              5
#                 Shelli            4
#                 Sigal             3
#         Martha  Steven            4
#         Timothy David             5
# East    Douglas Karen             3
#         Martha  Alexander         8
#                 Diana             2
# West    Douglas Michael           2
#         Timothy Stephen           4

# %% [markdown]
# 4. Write a Pandas program to create a Pivot table and find the item wise unit sold.

# %%
table =pd.pivot_table(df,index=['Item'],values='Units')
table
# Out:
#                   Units
# Item
# Cell Phone    55.600000
# Desk           3.333333
# Home Theater  48.133333
# Television    55.076923
# Video Games   56.428571

# %% [markdown]
# 5. Write a Pandas program to create a Pivot table and find the region wise total sale.

# %%
table =pd.pivot_table(df,index=['Region'],values='Units')
table
# Out:
#              Units
# Region
# Central  49.958333
# East     53.153846
# West     38.500000

# %% [markdown]
# 6. Write a Pandas program to create a Pivot table and find the region wise, item wise unit sold.

# %%
table =pd.pivot_table(df,index=['Region','Item'],values='Units')
table
# Out:
#                           Units
# Region  Item
# Central Cell Phone    27.000000
#         Desk           3.500000
#         Home Theater  53.000000
#         Television    55.333333
#         Video Games   60.750000
# East    Cell Phone    58.333333
#         Home Theater  46.800000
#         Television    65.000000
#         Video Games   50.666667
# West    Cell Phone    76.000000
#         Desk           3.000000
#         Home Theater  32.000000
#         Television    44.000000

# %% [markdown]
# 7. Write a Pandas program to create a Pivot table and count the manager wise sale and mean value of sale amount.

# %%
df=pd.read_csv('dataset/Saledata.csv')

print(pd.pivot_table(df,index=['Manager'],values=['Sale_amt'],aggfunc=[np.mean,len]))
# Out:
#              len
#         Sale_amt
# Manager
# Douglas        8
# Hermann       12
# Martha        14
# Timothy        9
# C:\Users\krish\AppData\Local\Temp\ipykernel_10928\2928265971.py:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   print(pd.pivot_table(df,index=['Manager'],values=['Sale_amt'],aggfunc=[np.mean,len]))

# %% [markdown]
# 8. Write a Pandas program to create a Pivot table and find manager wise, salesman wise total sale and also display the sum of all sale amount at the bottom.

# %%
amount =pd.pivot_table(df,index=['Manager','SalesMan'],values=['Sale_amt','Units'],aggfunc=[np.sum])
amount
# Out:
#                      sum
#                    Units
# Manager SalesMan
# Douglas John       156.0
#         Karen      170.0
#         Michael     89.0
# Hermann Luis       281.0
#         Shelli     193.0
#         Sigal      173.0
# Martha  Alexander  396.0
#         Diana      125.0
#         Steven     183.0
# Timothy David      213.0
#         Stephen    142.0

# %%
9. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise where Manager = "Douglas".

# %%
douglas = pd.pivot_table(df,index=['Region','Manager','SalesMan'],columns='Sale_amt').head()
print(douglas.query('Manager == ["Douglas"]'))
# Out:
#                                 Units                                       \
# Sale_amt                  107,820.00   113,810.00   14,000.00   14,400.00
# Region  Manager SalesMan
# Central Douglas John              NaN          NaN         NaN         NaN
#
#                                                                          \
# Sale_amt                  14,500.00   16,772.00   17,100.00   2,000.00
# Region  Manager SalesMan
# Central Douglas John             NaN         NaN         NaN        NaN
#
#                                                 ...                        \
# Sale_amt                  2,457.00   2,925.00   ...  5,616.00   6,075.00
# Region  Manager SalesMan                        ...
# Central Douglas John            NaN        NaN  ...        NaN        NaN
#
#                                                                        \
# Sale_amt                  625.00   63,494.00   67,088.00   79,068.00
# Region  Manager SalesMan
# Central Douglas John          NaN         NaN         NaN         NaN
#
#
# Sale_amt                  8,386.00   80,266.00   89,850.00   936.00
# Region  Manager SalesMan
# Central Douglas John            NaN        67.0         NaN      NaN
#
# [1 rows x 40 columns]

# %%
10. Write a Pandas program to create a Pivot table and find the region wise Television and Home Theater sold.

# %%
Television =pd.pivot_table(df,index=['Region','Item'],values='Units')
print(Television.query('Item == ["Television",Home Theater"]'))
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [69] in <cell line: 2>
#     print(Television.query('Item == ["Television",Home Theater"]'))
#
#   File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4111 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4240 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\eval.py:350 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:811 in __init__
#     self.terms = self.parse()
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:830 in parse
#     return self._visitor.visit(self.expr)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:411 in visit
#     raise e
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:407 in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File ~\anaconda3\lib\ast.py:50 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     Item ==["Television",Home Theater "]
#                               ^
# SyntaxError: invalid syntax

# %%
11. Write a Pandas program to create a Pivot table and find the maximum sale value of the items.

# %%
12. Write a Pandas program to create a Pivot table and find the minimum sale value of the items.

# %%
13.Write a Pandas program to create a Pivot table and find the maximum and minimum sale value of the items.
